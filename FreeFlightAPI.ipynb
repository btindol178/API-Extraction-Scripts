# %% [markdown]
# # Flights API
# https://rapidapi.com/skyscanner/api/skyscanner-flight-search?endpoint=5aa1eab3e4b00687d3574279
#
# ALSO USE THIS API
# https://pypi.org/project/skyscanner/

# %%
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/UK/GBP/en-GB/"

querystring = {"query":"Stockholm"}

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "Places" : [ {
#     "PlaceId" : "STOC-sky",
#     "PlaceName" : "Stockholm",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "ARN-sky",
#     "PlaceName" : "Stockholm Arlanda",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "NYO-sky",
#     "PlaceName" : "Stockholm Skavsta",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "BMA-sky",
#     "PlaceName" : "Stockholm Bromma",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   }, {
#     "PlaceId" : "VST-sky",
#     "PlaceName" : "Stockholm Vasteras",
#     "CountryId" : "SE-sky",
#     "RegionId" : "",
#     "CityId" : "STOC-sky",
#     "CountryName" : "Sweden"
#   } ]
# }

# %%
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/US/USA/en-US/"

querystring = {"query":"Detroit"}

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "Places" : [ {
#     "PlaceId" : "DTTA-sky",
#     "PlaceName" : "Detroit",
#     "CountryId" : "US-sky",
#     "RegionId" : "MI",
#     "CityId" : "DTTA-sky",
#     "CountryName" : "United States"
#   }, {
#     "PlaceId" : "DTW-sky",
#     "PlaceName" : "Detroit Wayne County",
#     "CountryId" : "US-sky",
#     "RegionId" : "MI",
#     "CityId" : "DTTA-sky",
#     "CountryName" : "United States"
#   }, {
#     "PlaceId" : "DET-sky",
#     "PlaceName" : "Detroit City",
#     "CountryId" : "US-sky",
#     "RegionId" : "MI",
#     "CityId" : "DTTA-sky",
#     "CountryName" : "United States"
#   }, {
#     "PlaceId" : "YIP-sky",
#     "PlaceName" : "Detroit Willow Run",
#     "CountryId" : "US-sky",
#     "RegionId" : "MI",
#     "CityId" : "DTTA-sky",
#     "CountryName" : "United States"
#   }, {
#     "PlaceId" : "DTL-sky",
#     "PlaceName" : "Detroit Lakes",
#     "CountryId" : "US-sky",
#     "RegionId" : "MN",
#     "CityId" : "DTLA-sky",
# ...

# %%
# Looking for flights to la in specific date range
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/US/USD/en-US/SFO-sky/LAX-sky/2021-03-01"

querystring = {"inboundpartialdate":"2021-03-01"}

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "Quotes" : [ {
#     "QuoteId" : 1,
#     "MinPrice" : 50,
#     "Direct" : false,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 1065 ],
#       "OriginId" : 81727,
#       "DestinationId" : 65368,
#       "DepartureDate" : "2021-03-01T00:00:00"
#     },
#     "QuoteDateTime" : "2021-02-18T22:23:00"
#   }, {
#     "QuoteId" : 2,
#     "MinPrice" : 98,
#     "Direct" : true,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 851 ],
#       "OriginId" : 81727,
#       "DestinationId" : 65368,
#       "DepartureDate" : "2021-03-01T00:00:00"
#     },
#     "QuoteDateTime" : "2021-02-18T22:23:00"
#   } ],
#   "Carriers" : [ {
#     "CarrierId" : 1065,
#     "Name" : "Frontier Airlines"
#   }, {
#     "CarrierId" : 851,
#     "Name" : "Alaska Airlines"
#   } ],
#   "Places" : [ {
#     "Name" : "Los Angeles International",
#     "Type" : "Station",
#     "PlaceId" : 65368,
#     "IataCode" : "LAX",
#     "SkyscannerCode" : "LAX",
#     "CityName" : "Los Angeles",
# ...

# %%
# Browse Quotes #SFO-sky to jfk
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/US/USD/en-US/SFO-sky/JFK-sky/2021-03-01"

querystring = {"inboundpartialdate":"2021-03-01"}

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "Quotes" : [ {
#     "QuoteId" : 1,
#     "MinPrice" : 165,
#     "Direct" : true,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 851 ],
#       "OriginId" : 81727,
#       "DestinationId" : 60987,
#       "DepartureDate" : "2021-03-01T00:00:00"
#     },
#     "QuoteDateTime" : "2021-02-18T17:06:00"
#   } ],
#   "Carriers" : [ {
#     "CarrierId" : 851,
#     "Name" : "Alaska Airlines"
#   } ],
#   "Places" : [ {
#     "Name" : "New York John F. Kennedy",
#     "Type" : "Station",
#     "PlaceId" : 60987,
#     "IataCode" : "JFK",
#     "SkyscannerCode" : "JFK",
#     "CityName" : "New York",
#     "CityId" : "NYCA",
#     "CountryName" : "United States"
#   }, {
#     "Name" : "San Francisco International",
#     "Type" : "Station",
#     "PlaceId" : 81727,
#     "IataCode" : "SFO",
#     "SkyscannerCode" : "SFO",
#     "CityName" : "San Francisco",
#     "CityId" : "SFOA",
#     "CountryName" : "United States"
#   } ],
#   "Currencies" : [ {
#     "Code" : "USD",
# ...

# %%
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/US/USD/en-US/DTW-sky/TPA-sky/2021-03-01"

querystring = {"inboundpartialdate":"2021-03-01"}

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "Quotes" : [ {
#     "QuoteId" : 1,
#     "MinPrice" : 28,
#     "Direct" : true,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 1467 ],
#       "OriginId" : 47847,
#       "DestinationId" : 84497,
#       "DepartureDate" : "2021-03-01T00:00:00"
#     },
#     "QuoteDateTime" : "2021-02-17T00:51:00"
#   } ],
#   "Carriers" : [ {
#     "CarrierId" : 1467,
#     "Name" : "Spirit Airlines"
#   } ],
#   "Places" : [ {
#     "Name" : "Detroit Wayne County",
#     "Type" : "Station",
#     "PlaceId" : 47847,
#     "IataCode" : "DTW",
#     "SkyscannerCode" : "DTW",
#     "CityName" : "Detroit",
#     "CityId" : "DTTA",
#     "CountryName" : "United States"
#   }, {
#     "Name" : "Tampa International",
#     "Type" : "Station",
#     "PlaceId" : 84497,
#     "IataCode" : "TPA",
#     "SkyscannerCode" : "TPA",
#     "CityName" : "Tampa",
#     "CityId" : "TPAA",
#     "CountryName" : "United States"
#   } ],
#   "Currencies" : [ {
#     "Code" : "USD",
#     "Symbol" : "$",
# ...

# %%
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/DTW-sky/TPA-sky/2021-03-01"

querystring = {"inboundpartialdate":"2021-03-01"}

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "Quotes" : [ {
#     "QuoteId" : 1,
#     "MinPrice" : 28,
#     "Direct" : true,
#     "OutboundLeg" : {
#       "CarrierIds" : [ 1467 ],
#       "OriginId" : 47847,
#       "DestinationId" : 84497,
#       "DepartureDate" : "2021-03-01T00:00:00"
#     },
#     "QuoteDateTime" : "2021-02-17T00:51:00"
#   } ],
#   "Carriers" : [ {
#     "CarrierId" : 1467,
#     "Name" : "Spirit Airlines"
#   } ],
#   "Places" : [ {
#     "Name" : "Detroit Wayne County",
#     "Type" : "Station",
#     "PlaceId" : 47847,
#     "IataCode" : "DTW",
#     "SkyscannerCode" : "DTW",
#     "CityName" : "Detroit",
#     "CityId" : "DTTA",
#     "CountryName" : "United States"
#   }, {
#     "Name" : "Tampa International",
#     "Type" : "Station",
#     "PlaceId" : 84497,
#     "IataCode" : "TPA",
#     "SkyscannerCode" : "TPA",
#     "CityName" : "Tampa",
#     "CityId" : "TPAA",
#     "CountryName" : "United States"
#   } ],
#   "Currencies" : [ {
#     "Code" : "USD",
#     "Symbol" : "$",
# ...

# %%
import requests
# USA US DOLLARS FROM DETROIT TO TAMPA LEAVING 2021-03-01 ARRIVING 03-11
url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/US/USD/en-US/DTW-sky/TPA-sky/%222021-03-01%22/%222021-03-11%22"

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "code" : 404,
#   "message" : "HTTP 404 Not Found"
# }

# %%
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/US/USD/en-US/DTW/TPA/%222021-03-01%22/%222021-03-11%22"

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "code" : 404,
#   "message" : "HTTP 404 Not Found"
# }

# %%
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/US/USD/en-US/DTW/TPA/%222021-03-05%22/%222021-03-11%22"

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "code" : 404,
#   "message" : "HTTP 404 Not Found"
# }

# %%
import requests

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/US/USD/en-US/DTW/TPA/%222021-07-01%22/%222021-07-10%22"

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {
#   "code" : 404,
#   "message" : "HTTP 404 Not Found"
# }

# %%
import http.client

conn = http.client.HTTPSConnection("skyscanner-skyscanner-flight-search-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "3098984b99msh9a120a8ade10e53p1ebdd1jsn7703d6e155d0",
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
    }

conn.request("GET", "/apiservices/browsedates/v1.0/US/USD/en-US/DTW/TPA/%222021-07-01%22/%222021-07-10%22", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {
#   "code" : 404,
#   "message" : "HTTP 404 Not Found"
# }
